# %% [markdown]
# <a href="https://colab.research.google.com/github/pano1215/Bigdata_analyst_certification-/blob/main/%5B%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D%EA%B8%B0%EC%82%AC_%EC%8B%A4%EA%B8%B0_Pandas_10%5D_csv_%ED%8C%8C%EC%9D%BC_%EA%B0%80%EC%A0%B8%EC%98%A4%EA%B8%B0%2C_%EA%B2%B0%EC%B8%A1%EC%B9%98_%ED%99%95%EC%9D%B8%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Soyoung-Yoon/data_01
# Out:
# Cloning into 'data_01'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 53 (delta 19), reused 53 (delta 19), pack-reused 0
# Unpacking objects: 100% (53/53), 5.48 MiB | 5.04 MiB/s, done.

# %%
# !pip install koreanize-matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 48.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
# 사용 예시!
import matplotlib.pyplot as plt
import koreanize_matplotlib
plt.figure(figsize=(4,3))
plt.plot([-1, 0, 1, 2])
plt.xlabel('간단한 그래프')
plt.show()

# %%
# drinks.csv

import pandas as pd
df = pd.read_csv('./data_01/drinks.csv')

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# [2-3] df의 컬럼명을 한글로 변경합니다.
# ['국가', '맥주', '증류주', '와인', '알코올','대륙']
df.columns = ['국가', '맥주', '증류주', '와인', '알코올','대륙']

# 변경되었는지 확인합니다.
df
# Out:
#               국가   맥주  증류주   와인   알코올  대륙
# 0    Afghanistan    0    0    0   0.0  AS
# 1        Albania   89  132   54   4.9  EU
# 2        Algeria   25    0   14   0.7  AF
# 3        Andorra  245  138  312  12.4  EU
# 4         Angola  217   57   45   5.9  AF
# ..           ...  ...  ...  ...   ...  ..
# 188    Venezuela  333  100    3   7.7  SA
# 189      Vietnam  111    2    1   2.0  AS
# 190        Yemen    6    0    0   0.1  AS
# 191       Zambia   32   19    4   2.5  AF
# 192     Zimbabwe   64   18    4   4.7  AF
#
# [193 rows x 6 columns]

# %%
# [2-4] df의 row의 개수 및 각 column의 정보 및 메모리 사용량을 확인합니다.
df.info('memory usage')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국가      193 non-null    object
#  1   맥주      193 non-null    int64
#  2   증류주     193 non-null    int64
#  3   와인      193 non-null    int64
#  4   알코올     193 non-null    float64
#  5   대륙      170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
# '대륙'에 대한 정보가 부족한 것을 확인할 수 있습니다.
# 이유가 무엇일까요? 어떻게 해결할 수 있을까요?

# %%
# drinks.csv 파일을 열어 원인을 확인하여 보도록 합니다.

# %%
df.isna().all()
# Out:
# 국가     False
# 맥주     False
# 증류주    False
# 와인     False
# 알코올    False
# 대륙     False
# dtype: bool

# %%
df.isna().any()
# Out:
# 국가     False
# 맥주     False
# 증류주    False
# 와인     False
# 알코올    False
# 대륙      True
# dtype: bool

# %%
# [2-5] 대륙의 종류를 알아봅니다
# 결과를 보면 csv파일에서 'NA'로 되어 있는 데이터를 NaN(=nan)으로 가져온 것입니다.
df['대륙'].unique()
# Out:
# array(['AS', 'EU', 'AF', nan, 'SA', 'OC'], dtype=object)

# %%
pd.Series(df['대륙'].unique())
# Out:
# 0     AS
# 1     EU
# 2     AF
# 3    NaN
# 4     SA
# 5     OC
# dtype: object

# %%
# [2-6] 대륙별 개수를 알아봅니다.
df['대륙'].value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: 대륙, dtype: int64

# %%
# [2-7] 결측치를 컬럼 별로 집계해 봅니다.
df.isna().sum()
# Out:
# 국가      0
# 맥주      0
# 증류주     0
# 와인      0
# 알코올     0
# 대륙     23
# dtype: int64

# %%
# [2-8] isna()를 사용해 대륙에서 결측치로 취급된 데이터만 출력해 봅니다
# 북아메리카(NA)에 포함되는 국가들인 것을 확인할 수 있습니다.
df[df['대륙'].isna()]
# Out:
#                                국가   맥주  증류주   와인   알코올   대륙
# 5               Antigua & Barbuda  102  128   45   4.9  NaN
# 11                        Bahamas  122  176   51   6.3  NaN
# 14                       Barbados  143  173   36   6.3  NaN
# 17                         Belize  263  114    8   6.8  NaN
# 32                         Canada  240  122  100   8.2  NaN
# 41                     Costa Rica  149   87   11   4.4  NaN
# 43                           Cuba   93  137    5   4.2  NaN
# 50                       Dominica   52  286   26   6.6  NaN
# 51             Dominican Republic  193  147    9   6.2  NaN
# 54                    El Salvador   52   69    2   2.2  NaN
# 68                        Grenada  199  438   28  11.9  NaN
# 69                      Guatemala   53   69    2   2.2  NaN
# 73                          Haiti    1  326    1   5.9  NaN
# 74                       Honduras   69   98    2   3.0  NaN
# 84                        Jamaica   82   97    9   3.4  NaN
# 109                        Mexico  238   68    5   5.5  NaN
# 122                     Nicaragua   78  118    1   3.5  NaN
# 130                        Panama  285  104   18   7.2  NaN
# 143             St. Kitts & Nevis  194  205   32   7.7  NaN
# 144                     St. Lucia  171  315   71  10.1  NaN
# 145  St. Vincent & the Grenadines  120  221   11   6.3  NaN
# 174             Trinidad & Tobago  197  156    7   6.4  NaN
# 184                           USA  249  158   84   8.7  NaN

# %% [markdown]
# #[빅데이터 분석기사 실기 - Pandas 11] 결측치 처리, df.fillna(값)

# %%
# [2-9] 해결방법 1
# read_csv의 옵션을 사용하여 해결합니다.
# read_csv에서 'NA'를 NaN으로 읽도록하는 동작을 멈추게 합니다.
# na_filter=False 를 사용하면 NA를 NaN으로 읽지 않습니다.
temp = pd.read_csv('data_01/drinks.csv', na_filter = False)

# %%
# [2-10] df2의 'continent' (대륙)에 포함된 값의 종류를 unique를 사용해 살펴 봅니다
# NaN 대신 'NA'가 있는 것을 확인할 수 있습니다.
temp['continent'].unique()
# Out:
# array(['AS', 'EU', 'AF', 'NA', 'SA', 'OC'], dtype=object)

# %%
temp.isna().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
# [2-10] 해결방법 2
# NaN으로 읽어온 데이터를 'NA'로 변경합니다.
df['대륙'] = df['대륙'].fillna('NA')

# %%
df.loc[df['대륙'].isna(), '대륙'] = 'NA'
df = df.fillna('NA')

# %%
# [2-11] 결측치가 제거 되었는지 컬럼 별 결측치 개수를 출력해 확인합니다.
df.isna().sum()
# Out:
# 국가     0
# 맥주     0
# 증류주    0
# 와인     0
# 알코올    0
# 대륙     0
# dtype: int64

# %%
# [2-12] unique()를 사용하여 '대륙'의 종류를 확인해 봅니다.
df['대륙'].unique()
# Out:
# array(['AS', 'EU', 'AF', 'NA', 'SA', 'OC'], dtype=object)

# %% [markdown]
# # [빅데이터 분석기사 실기 - Pandas 12] DataFrame의 통계값 구하기

# %%
df.head(2)
# Out:
#             국가  맥주  증류주  와인  알코올  대륙
# 0  Afghanistan   0    0   0  0.0  AS
# 1      Albania  89  132  54  4.9  EU

# %%
# [2-13] describe 함수를 사용해 전세계 맥주, 증류주, 와인, 알코올 소비에 대한 통계치를 구해봅니다.
df.describe()
# Out:
#                맥주         증류주          와인         알코올
# count  193.000000  193.000000  193.000000  193.000000
# mean   106.160622   80.994819   49.450777    4.717098
# std    101.143103   88.284312   79.697598    3.773298
# min      0.000000    0.000000    0.000000    0.000000
# 25%     20.000000    4.000000    1.000000    1.300000
# 50%     76.000000   56.000000    8.000000    4.200000
# 75%    188.000000  128.000000   59.000000    7.200000
# max    376.000000  438.000000  370.000000   14.400000

# %%
temp = df[['국가', '대륙']]
temp.describe()
# Out:
#                  국가   대륙
# count           193  193
# unique          193    6
# top     Afghanistan   AF
# freq              1   53

# %%
# [2-14] 전세계 맥주, 증류주, 와인, 알코올 소비에 대한 정보만 추출하여 df2로 지정합니다.
df2 = df[['맥주', '증류주', '와인', '알코올']]
df2.head(2)
# Out:
#    맥주  증류주  와인  알코올
# 0   0    0   0  0.0
# 1  89  132  54  4.9

# %%
# [2-15] 전세계 맥주, 증류주, 와인, 알코올의 소비에 대한 (df2) '평균'만 구해봅니다.
df2.mean()
# Out:
# 맥주     106.160622
# 증류주     80.994819
# 와인      49.450777
# 알코올      4.717098
# dtype: float64

# %%
# [2-16] 전세계 맥주, 증류주, 와인, 알코올의 소비에 대한 (df2) '중앙값'만 구해봅니다.
df2.median()
# Out:
# 맥주     76.0
# 증류주    56.0
# 와인      8.0
# 알코올     4.2
# dtype: float64

# %%
# [2-17] 전세계 맥주, 증류주, 와인, 알코올의 소비에 대한 '최대값'만 구해봅니다.
df2.max()
# Out:
# 맥주     376.0
# 증류주    438.0
# 와인     370.0
# 알코올     14.4
# dtype: float64

# %%
# [2-18] 전세계 맥주, 증류주, 와인, 알코올의 소비에 대한 '최소값'만 구해봅니다.
df2.min()
# Out:
# 맥주     0.0
# 증류주    0.0
# 와인     0.0
# 알코올    0.0
# dtype: float64

# %%
# [2-19] 전세계 맥주, 증류주, 와인, 알코올의 소비에 대한 (df2) Q1, Q2, Q3를 구해봅니다.
temp = df2.quantile([0.25, 0.5, 0.75])
temp.index = ['Q1', 'Q2', 'Q3']
temp
# Out:
#        맥주    증류주    와인  알코올
# Q1   20.0    4.0   1.0  1.3
# Q2   76.0   56.0   8.0  4.2
# Q3  188.0  128.0  59.0  7.2

# %%
# 표준편차(std), 분산(var)에 대해서도 작업해 보세요 ^_^!!!
df2.std(), df2.var()
# Out:
# (맥주     101.143103
#  증류주     88.284312
#  와인      79.697598
#  알코올      3.773298
#  dtype: float64,
#  맥주     10229.927191
#  증류주     7794.119765
#  와인      6351.707200
#  알코올       14.237779
#  dtype: float64)

# %%
ord('0'), ord('1'), ord('A'), ord('a'), ord('B'), ord('b')
# Out:
# (48, 49, 65, 97, 66, 98)

# %%
# [2-20] df (object dtype이 존재함) 에 대해서 컬럼별 min을 구해 봅니다.
# dtype이 object이 컬럼의 min은 오름차순 정렬시 가장 앞에 있는 것
# dtype이 object이 컬럼의 max는 오름차순 정렬시 가장 뒤에 있는 것
# 문자열 정렬시에는 문자의 코드값을 사용함 : ord(문자)
df.min(), df.max()
# Out:
# (국가     Afghanistan
#  맥주               0
#  증류주              0
#  와인               0
#  알코올            0.0
#  대륙              AF
#  dtype: object,
#  국가     Zimbabwe
#  맥주          376
#  증류주         438
#  와인          370
#  알코올        14.4
#  대륙           SA
#  dtype: object)

# %%
# [2-21] df2의 각 컬럼별 평균을 구해 봅니다.
df2.apply('mean')
# Out:
# 맥주     106.160622
# 증류주     80.994819
# 와인      49.450777
# 알코올      4.717098
# dtype: float64

# %%
df2.mean()
# Out:
# 맥주     106.160622
# 증류주     80.994819
# 와인      49.450777
# 알코올      4.717098
# dtype: float64

# %%
# [2-22] df2의 최소, 최대, 평균값을 구해봅니다.
df2.apply(['min', 'max', 'mean'])
# Out:
#               맥주         증류주          와인        알코올
# min     0.000000    0.000000    0.000000   0.000000
# max   376.000000  438.000000  370.000000  14.400000
# mean  106.160622   80.994819   49.450777   4.717098

# %% [markdown]
# # [빅데이터 분석기사 실기 - Pandas 13] 컬럼, 행의 추가/삭제

# %%
# pandas의 max_rows, max_columns 설정
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 10)
# https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html

# %%
# [2-23] 와인 소비량이 맥주 + 증류주 소비량보다 큰 나라를 검색해,'대륙'을 기준으로 정렬해 보자
df[df['와인'] > df['맥주'] + df['증류주']].sort_values('대륙', ascending = True)
# Out:
#                       국가   맥주  증류주   와인   알코올  대륙
# 55     Equatorial Guinea   92    0  233   5.8  AF
# 148  Sao Tome & Principe   56   38  140   4.2  AF
# 92                  Laos   62    0  123   6.2  AS
# 171          Timor-Leste    1    1    4   0.1  AS
# 61                France  127  151  370  11.8  EU
# 83                 Italy   85   42  237   6.5  EU
# 136             Portugal  194   67  339  11.0  EU
# 6              Argentina  193   25  221   8.3  SA
# 185              Uruguay  115   35  220   6.6  SA

# %%
# [2-24] 맥주 소비량이 230 초과이면서, 와인 소비량이 230 초과인 나라를 검색해 보자
df[(df['맥주'] > 230) & (df['와인'] > 230)]
# Out:
#              국가   맥주  증류주   와인   알코올  대륙
# 3       Andorra  245  138  312  12.4  EU
# 99   Luxembourg  236  133  271  11.4  EU
# 156    Slovenia  270   51  276  10.6  EU

# %%
# [2-25] 대륙이 'AS'인 국가들의 정보를 검색해 보자
df[df['대륙'] == 'AS']
# Out:
#                        국가   맥주  증류주   와인   알코올  대륙
# 0             Afghanistan    0    0    0   0.0  AS
# 12                Bahrain   42   63    7   2.0  AS
# 13             Bangladesh    0    0    0   0.0  AS
# 19                 Bhutan   23    0    0   0.4  AS
# 24                 Brunei   31    2    1   0.6  AS
# 30               Cambodia   57   65    1   2.2  AS
# 36                  China   79  192    8   5.0  AS
# 46            North Korea    0    0    0   0.0  AS
# 77                  India    9  114    0   2.2  AS
# 78              Indonesia    5    1    0   0.1  AS
# 79                   Iran    0    0    0   0.0  AS
# 80                   Iraq    9    3    0   0.2  AS
# 82                 Israel   63   69    9   2.5  AS
# 85                  Japan   77  202   16   7.0  AS
# 86                 Jordan    6   21    1   0.5  AS
# 87             Kazakhstan  124  246   12   6.8  AS
# 90                 Kuwait    0    0    0   0.0  AS
# 91             Kyrgyzstan   31   97    6   2.4  AS
# 92                   Laos   62    0  123   6.2  AS
# 94                Lebanon   20   55   31   1.9  AS
# 102              Malaysia   13    4    0   0.3  AS
# 103              Maldives    0    0    0   0.0  AS
# 112              Mongolia   77  189    8   4.9  AS
# 116               Myanmar    5    1    0   0.1  AS
# 119                 Nepal    5    6    0   0.2  AS
# 127                  Oman   22   16    1   0.7  AS
# 128              Pakistan    0    0    0   0.0  AS
# 134           Philippines   71  186    1   4.6  AS
# 137                 Qatar    1   42    7   0.9  AS
# 138           South Korea  140   16    9   9.8  AS
# 141    Russian Federation  247  326   73  11.5  AS
# 149          Saudi Arabia    0    5    0   0.1  AS
# 154             Singapore   60   12   11   1.5  AS
# 161             Sri Lanka   16  104    0   2.2  AS
# 167                 Syria    5   35   16   1.0  AS
# 168            Tajikistan    2   15    0   0.3  AS
# 169              Thailand   99  258    1   6.4  AS
# 171           Timor-Leste    1    1    4   0.1  AS
# 176                Turkey   51   22    7   1.4  AS
# 177          Turkmenistan   19   71   32   2.2  AS
# 181  United Arab Emirates   16  135    5   2.8  AS
# 186            Uzbekistan   25  101    8   2.4  AS
# 189               Vietnam  111    2    1   2.0  AS
# 190                 Yemen    6    0    0   0.1  AS

# %%
# [2-26] 국가별 주류 소비량 합계를 구해 새로운 컬럼 ('주류소비량')를 추가합니다
# 주류소비량 = '맥주' + '증류주' + '와인'
df['주류소비량'] = df['맥주'] + df['증류주'] + df['와인']
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량
# 0  Afghanistan    0    0    0   0.0  AS      0
# 1      Albania   89  132   54   4.9  EU    275
# 2      Algeria   25    0   14   0.7  AF     39
# 3      Andorra  245  138  312  12.4  EU    695
# 4       Angola  217   57   45   5.9  AF    319

# %%
# [2-27] 주류소비량2 = ['맥주', '증류주', '와인']에 대해 DataFrame.sum(axis=1) 함수 사용
df['주류소비량2'] = df[['맥주', '증류주', '와인']].sum(axis = 1)
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량  주류소비량2
# 0  Afghanistan    0    0    0   0.0  AS      0       0
# 1      Albania   89  132   54   4.9  EU    275     275
# 2      Algeria   25    0   14   0.7  AF     39      39
# 3      Andorra  245  138  312  12.4  EU    695     695
# 4       Angola  217   57   45   5.9  AF    319     319

# %%
# [2-28] 주류 소비량 대비 알코올 소비량 비율을 구해 새로운 컬럼 ('알코올비율')을 추가합니다.
# 알코올비율 = '알코올' / '주류소비량'
df['알코올비율'] = df['알코올'] / df['주류소비량']
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량  주류소비량2     알코올비율
# 0  Afghanistan    0    0    0   0.0  AS      0       0       NaN
# 1      Albania   89  132   54   4.9  EU    275     275  0.017818
# 2      Algeria   25    0   14   0.7  AF     39      39  0.017949
# 3      Andorra  245  138  312  12.4  EU    695     695  0.017842
# 4       Angola  217   57   45   5.9  AF    319     319  0.018495

# %%
# [2-29] 알코올비율이 높은 국가 TOP5의 ['국가', '주류소비량', '알코올비율'] 정보를 구해 봅니다.
# HINT) sort_values, indexing 사용
df[['국가', '주류소비량', '알코올비율']].sort_values('알코올비율', ascending = False).head()
# Out:
#                국가  주류소비량     알코올비율
# 63         Gambia      9  0.266667
# 153  Sierra Leone     30  0.223333
# 124       Nigeria     49  0.185714
# 179        Uganda     54  0.153704
# 142        Rwanda     45  0.151111

# %%
df['주류소비량2'] = df['주류소비량'].copy()

# %%
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량  주류소비량2     알코올비율
# 0  Afghanistan    0    0    0   0.0  AS      0       0       NaN
# 1      Albania   89  132   54   4.9  EU    275     275  0.017818
# 2      Algeria   25    0   14   0.7  AF     39      39  0.017949
# 3      Andorra  245  138  312  12.4  EU    695     695  0.017842
# 4       Angola  217   57   45   5.9  AF    319     319  0.018495

# %%
# [2-30] '주류소비량2' 컬럼을 제거하여 봅니다.
#df = df.drop('주류소비량2', axis=1)
#df = df.drop(columns=['주류소비량2'])
df = df.drop(columns = ['주류소비량2'])
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량     알코올비율
# 0  Afghanistan    0    0    0   0.0  AS      0       NaN
# 1      Albania   89  132   54   4.9  EU    275  0.017818
# 2      Algeria   25    0   14   0.7  AF     39  0.017949
# 3      Andorra  245  138  312  12.4  EU    695  0.017842
# 4       Angola  217   57   45   5.9  AF    319  0.018495

# %%
df = df.drop('주류소비량2', axis = 1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-95b4ccac0106> in <cell line: 1>()
# ----> 1 df = df.drop('주류소비량2', axis = 1)
#       2 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['주류소비량2'] not found in axis"

# %%
del df['주류소비량2']
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '주류소비량2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-23a09a65ea72> in <cell line: 1>()
# ----> 1 del df['주류소비량2']
#       2 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __delitem__(self, key)
#    4241             # there was no match, this call should raise the appropriate
#    4242             # exception:
# -> 4243             loc = self.axes[-1].get_loc(key)
#    4244             self._mgr = self._mgr.idelete(loc)
#    4245
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '주류소비량2'

# %%
# [2-31] '알코올비율'이 NaN인 것에 대해 0으로 채우기 합니다.
df['알코올비율'] = df['알코올비율'].fillna(0)

# %%
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량     알코올비율
# 0  Afghanistan    0    0    0   0.0  AS      0  0.000000
# 1      Albania   89  132   54   4.9  EU    275  0.017818
# 2      Algeria   25    0   14   0.7  AF     39  0.017949
# 3      Andorra  245  138  312  12.4  EU    695  0.017842
# 4       Angola  217   57   45   5.9  AF    319  0.018495

# %% [markdown]
# # [빅데이터 분석기사 실기 - Pandas 14] 다양한 데이터 프레임 구조 조작

# %%
# [2-32] 국가별 주류 소비량 합계(맥주, 증류주, 와인의 합)를 구해 봅니다.
df.set_index('국가')[['맥주', '증류주', '와인']].sum(axis = 1)
# Out:
# 국가
# Afghanistan                       0
# Albania                         275
# Algeria                          39
# Andorra                         695
# Angola                          319
# Antigua & Barbuda               275
# Argentina                       439
# Armenia                         211
# Australia                       545
# Austria                         545
# Azerbaijan                       72
# Bahamas                         349
# Bahrain                         112
# Bangladesh                        0
# Barbados                        352
# Belarus                         557
# Belgium                         591
# Belize                          385
# Benin                            51
# Bhutan                           23
# Bolivia                         216
# Bosnia-Herzegovina              257
# Botswana                        243
# Brazil                          406
# Brunei                           34
# Bulgaria                        577
# Burkina Faso                     39
# Burundi                          88
# Cote d'Ivoire                    45
# Cabo Verde                      216
# Cambodia                        123
# Cameroon                        152
# Canada                          462
# Central African Republic         20
# Chad                             17
# Chile                           426
# China                           279
# Colombia                        238
# Comoros                           5
# Congo                            86
# Cook Islands                    328
# Costa Rica                      247
# Croatia                         571
# Cuba                            235
# Cyprus                          459
# Czech Republic                  665
# North Korea                       0
# DR Congo                         36
# Denmark                         583
# Djibouti                         62
# Dominica                        364
# Dominican Republic              349
# Ecuador                         239
# Egypt                            11
# El Salvador                     123
# Equatorial Guinea               325
# Eritrea                          18
# Estonia                         477
# Ethiopia                         23
# Fiji                            113
# Finland                         493
# France                          648
# Gabon                           504
# Gambia                            9
# Georgia                         301
# Germany                         638
# Ghana                            44
# Greece                          463
# Grenada                         665
# Guatemala                       124
# Guinea                           11
# Guinea-Bissau                    80
# Guyana                          396
# Haiti                           328
# Honduras                        169
# Hungary                         634
# Iceland                         372
# India                           123
# Indonesia                         6
# Iran                              0
# Iraq                             12
# Ireland                         596
# Israel                          141
# Italy                           364
# Jamaica                         188
# Japan                           295
# Jordan                           28
# Kazakhstan                      382
# Kenya                            82
# Kiribati                         56
# Kuwait                            0
# Kyrgyzstan                      134
# Laos                            185
# Latvia                          559
# Lebanon                         106
# Lesotho                         111
# Liberia                         173
# Libya                             0
# Lithuania                       643
# Luxembourg                      640
# Madagascar                       45
# Malawi                           20
# Malaysia                         17
# Maldives                          0
# Mali                              7
# Malta                           369
# Marshall Islands                  0
# Mauritania                        0
# Mauritius                       147
# Mexico                          311
# Micronesia                      130
# Monaco                            0
# Mongolia                        274
# Montenegro                      273
# Morocco                          28
# Mozambique                       70
# Myanmar                           6
# Namibia                         380
# Nauru                            57
# Nepal                            11
# Netherlands                     529
# New Zealand                     457
# Nicaragua                       197
# Niger                             6
# Nigeria                          49
# Niue                            395
# Norway                          369
# Oman                             39
# Pakistan                          0
# Palau                           392
# Panama                          407
# Papua New Guinea                 84
# Paraguay                        404
# Peru                            344
# Philippines                     258
# Poland                          614
# Portugal                        600
# Qatar                            50
# South Korea                     165
# Moldova                         353
# Romania                         586
# Russian Federation              646
# Rwanda                           45
# St. Kitts & Nevis               431
# St. Lucia                       557
# St. Vincent & the Grenadines    352
# Samoa                           147
# San Marino                        0
# Sao Tome & Principe             234
# Saudi Arabia                      5
# Senegal                          17
# Serbia                          541
# Seychelles                      233
# Sierra Leone                     30
# Singapore                        83
# Slovakia                        605
# Slovenia                        597
# Solomon Islands                  68
# Somalia                           0
# South Africa                    382
# Spain                           553
# Sri Lanka                       120
# Sudan                            21
# Suriname                        313
# Swaziland                        94
# Sweden                          398
# Switzerland                     565
# Syria                            56
# Tajikistan                       17
# Thailand                        358
# Macedonia                       219
# Timor-Leste                       6
# Togo                             57
# Tonga                            62
# Trinidad & Tobago               360
# Tunisia                          74
# Turkey                           80
# Turkmenistan                    122
# Tuvalu                           56
# Uganda                           54
# Ukraine                         488
# United Arab Emirates            156
# United Kingdom                  540
# Tanzania                         43
# USA                             491
# Uruguay                         370
# Uzbekistan                      134
# Vanuatu                          50
# Venezuela                       436
# Vietnam                         114
# Yemen                             6
# Zambia                           55
# Zimbabwe                         86
# dtype: int64

# %%
# [2-33] df를 ['대륙', '국가']를 index로 지정하고, 대륙별, 국가명으로  정렬하여 df로 저장합니다.
df = df.set_index(['대륙', '국가']).sort_index()

# %%
# [2-34] df의 index를 모두 columns로 이동합니다.
df = df.reset_index()

# %%
# [2-35] 전세계 평균 소비량과 한국('South Korea')의 소비량을 비교해 보려고 합니다.
# 먼저, 한국의 소비량을 조회하여 korea로 저장합니다.
korea = df[df['국가'] == 'South Korea']
korea
# Out:
#     대륙           국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  AS  South Korea  140   16   9  9.8    165  0.059394

# %%
# [2-36] korea 정보 중에서 대륙 정보를 제거합니다.
korea.drop('대륙', axis = 1)
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
korea
# Out:
#     대륙           국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  AS  South Korea  140   16   9  9.8    165  0.059394

# %%
# [2-37] indexing을 사용하여 korea 정보 중 대륙 정보를 제거합니다. (DataFrame.loc[])
korea.loc[:, '국가':'알코올비율']
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
df.loc[df['국가'] == 'South Korea', '국가':'알코올비율']
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
# [2-38] indexing을 사용하여 korea 정보 중 대륙 정보를 제거합니다. (DataFrame.iloc[])
korea.iloc[:, 1:]
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
df.iloc[(df['국가'] == 'South Korea').to_list(), 1:]
# iloc을 쓸 때 시리즈를 쓰면 안댐
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
# [2-39] korea에 대륙 정보가 제거된 정보를 다시 저장합니다.
korea = korea.drop('대륙', axis = 1)
korea
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
pd.DataFrame(df.mean())
# Out:
# <ipython-input-68-53c9c07e1a87>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pd.DataFrame(df.mean())
#                 0
# 맥주     106.160622
# 증류주     80.994819
# 와인      49.450777
# 알코올      4.717098
# 주류소비량  236.606218
# 알코올비율    0.026115

# %%
# [2-40] 세계의 각 컬럼별 평균을 구하여 DataFrame으로 만들고,
# worldwide라는 이름을 지정합니다
# 세계의 각 컬럼별 평균은 DataFrame.mean()을 사용합니다.
worldwide = pd.DataFrame(df.mean())
worldwide
# Out:
# <ipython-input-69-eed94b699348>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   worldwide = pd.DataFrame(df.mean())
#                 0
# 맥주     106.160622
# 증류주     80.994819
# 와인      49.450777
# 알코올      4.717098
# 주류소비량  236.606218
# 알코올비율    0.026115

# %%
# [2-41] worldwide의 행과 열을 전환해 wwT로 저장합니다.
wwT = worldwide.T
wwT
# Out:
#            맥주        증류주         와인       알코올       주류소비량     알코올비율
# 0  106.160622  80.994819  49.450777  4.717098  236.606218  0.026115

# %%
korea
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
# [2-42] wwT의 맨 앞에 '국가' 컬럼을 'World Wide' 값으로 추가합니다.
# 여러 번 추가하면 안됨
wwT.insert(0, '국가', 'worldwide')
wwT
# Out:
#           국가          맥주        증류주         와인       알코올       주류소비량     알코올비율
# 0  worldwide  106.160622  80.994819  49.450777  4.717098  236.606218  0.026115

# %%
wwT
# Out:
#           국가          맥주        증류주         와인       알코올       주류소비량     알코올비율
# 0  worldwide  106.160622  80.994819  49.450777  4.717098  236.606218  0.026115

# %%
# [2-43] korea 뒤에 wwT를 추가하여 compT 로 이름 붙입니다
compT = korea.append(wwT)
compT
# Out:
# <ipython-input-74-84b47e5731ad>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compT = korea.append(wwT)
#              국가          맥주        증류주         와인       알코올       주류소비량  \
# 85  South Korea  140.000000  16.000000   9.000000  9.800000  165.000000
# 0     worldwide  106.160622  80.994819  49.450777  4.717098  236.606218
#
#        알코올비율
# 85  0.059394
# 0   0.026115

# %%
# 한국의 맥주 및 알코올 소비량이 전세계 맥주 소비량보다 많은 것을 알 수 있습니다.

# %%
# [2-44] wwT와 korea 를 합쳐 하나의 DataFrame을 생성하여 df2로 저장합니다.
df2 = pd.concat([korea, wwT])
df2
# Out:
#              국가          맥주        증류주         와인       알코올       주류소비량  \
# 85  South Korea  140.000000  16.000000   9.000000  9.800000  165.000000
# 0     worldwide  106.160622  80.994819  49.450777  4.717098  236.606218
#
#        알코올비율
# 85  0.059394
# 0   0.026115

# %%
# [2-45] df2를 '국가' 컬럼을 index로 설정하여 df3으로 저장합니다
df3 = df2.set_index('국가')
df3
# Out:
#                      맥주        증류주         와인       알코올       주류소비량     알코올비율
# 국가
# South Korea  140.000000  16.000000   9.000000  9.800000  165.000000  0.059394
# worldwide    106.160622  80.994819  49.450777  4.717098  236.606218  0.026115

# %%
# [2-46] df3의 행,열을 전환하여 출력합니다.
df3.T
# Out:
# 국가     South Korea   worldwide
# 맥주      140.000000  106.160622
# 증류주      16.000000   80.994819
# 와인        9.000000   49.450777
# 알코올       9.800000    4.717098
# 주류소비량   165.000000  236.606218
# 알코올비율     0.059394    0.026115

# %% [markdown]
# # [빅데이터 분석기사 실기 - Pandas 15] 맥주 소비량 분석

# %%
# [2-47] 주류소비량이 있으면서, 맥주를 소비하지 않는 나라의 맥주, 증류주, 와인, 알코올, 대륙 등 모든 정보를 구해 봅니다.
# indexing 사용
df[(df['주류소비량'] > 0) & (df['맥주'] == 0)]
# Out:
#      대륙            국가  맥주  증류주  와인  알코올  주류소비량     알코올비율
# 83   AS  Saudi Arabia   0    5   0  0.1      5  0.020000
# 166  OC  Cook Islands   0  254  74  5.9    328  0.017988

# %%
df.loc[(df['주류소비량'] > 0) & (df['맥주'] == 0), '대륙':]
# Out:
#      대륙            국가  맥주  증류주  와인  알코올  주류소비량     알코올비율
# 83   AS  Saudi Arabia   0    5   0  0.1      5  0.020000
# 166  OC  Cook Islands   0  254  74  5.9    328  0.017988

# %%
# [2-48] 주류소비량이 있으면서, 맥주를 소비하지 않는 국가의 국가명 목록을 구해봅니다.
df[(df['주류소비량'] > 0) & (df['맥주'] == 0)]['국가'].to_list()
# Out:
# ['Saudi Arabia', 'Cook Islands']

# %%
df[(df['주류소비량'] > 0) & (df['맥주'] == 0)]['국가']
# Out:
# 83     Saudi Arabia
# 166    Cook Islands
# Name: 국가, dtype: object

# %%
df.loc[(df['주류소비량'] > 0) & (df['맥주'] == 0), '국가']
# Out:
# 83     Saudi Arabia
# 166    Cook Islands
# Name: 국가, dtype: object

# %%
df.loc[(df['주류소비량'] > 0) & (df['맥주'] == 0), '국가'].to_list()
# Out:
# ['Saudi Arabia', 'Cook Islands']

# %%
# [2-49] 주류소비량이 정보가 없는 국가의 정보를 구해 봅니다.
df[df['주류소비량'] == 0]
# Out:
#      대륙                국가  맥주  증류주  와인  알코올  주류소비량  알코올비율
# 27   AF             Libya   0    0   0  0.0      0    0.0
# 31   AF        Mauritania   0    0   0  0.0      0    0.0
# 43   AF           Somalia   0    0   0  0.0      0    0.0
# 53   AS       Afghanistan   0    0   0  0.0      0    0.0
# 55   AS        Bangladesh   0    0   0  0.0      0    0.0
# 62   AS              Iran   0    0   0  0.0      0    0.0
# 68   AS            Kuwait   0    0   0  0.0      0    0.0
# 73   AS          Maldives   0    0   0  0.0      0    0.0
# 77   AS       North Korea   0    0   0  0.0      0    0.0
# 79   AS          Pakistan   0    0   0  0.0      0    0.0
# 126  EU            Monaco   0    0   0  0.0      0    0.0
# 133  EU        San Marino   0    0   0  0.0      0    0.0
# 169  OC  Marshall Islands   0    0   0  0.0      0    0.0

# %%
df[df['주류소비량'] == 0]['국가'].to_list()
# Out:
# ['Libya',
#  'Mauritania',
#  'Somalia',
#  'Afghanistan',
#  'Bangladesh',
#  'Iran',
#  'Kuwait',
#  'Maldives',
#  'North Korea',
#  'Pakistan',
#  'Monaco',
#  'San Marino',
#  'Marshall Islands']

# %%
# [2-50] 맥주 소비량의 값이 큰 5개 국가를 알아봅니다.
df.sort_values('맥주', ascending = False).head()
# Out:
#      대륙              국가   맥주  증류주   와인   알코올  주류소비량     알코올비율
# 35   AF         Namibia  376    3    1   6.8    380  0.017895
# 108  EU  Czech Republic  361  170  134  11.8    665  0.017744
# 19   AF           Gabon  347   98   59   8.9    504  0.017659
# 114  EU         Germany  346  117  175  11.3    638  0.017712
# 121  EU       Lithuania  343  244   56  12.9    643  0.020062

# %%
# [2-51] 맥주 소비량이 세계 평균 소비량보다 큰 국가의 개수는?
worldwide.T
# Out:
#            맥주        증류주         와인       알코올       주류소비량     알코올비율
# 0  106.160622  80.994819  49.450777  4.717098  236.606218  0.026115

# %%
df['맥주'] > worldwide['주류소비량']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-5f23a677fdc2> in <cell line: 1>()
# ----> 1 df['맥주'] > worldwide['주류소비량']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     393                     raise KeyError(key) from err
#     394             self._check_indexing_error(key)
# --> 395             raise KeyError(key)
#     396         return super().get_loc(key, method=method, tolerance=tolerance)
#     397
#
# KeyError: '주류소비량'

# %%
df.loc[df['맥주'] > df['맥주'].mean(), '국가'].count()
# Out:
# 76

# %% [markdown]
# # [빅데이터 분석기사 실기 - Pandas 16] 그룹별 통계값 구하기

# %%
# [2-52] 전세계 주류 소비량 평균
df.mean()
# Out:
# <ipython-input-93-b702ab6aa689>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# 맥주       106.160622
# 증류주       80.994819
# 와인        49.450777
# 알코올        4.717098
# 주류소비량    236.606218
# 알코올비율      0.026115
# dtype: float64

# %%
df.head(2)
# Out:
#    대륙       국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 0  AF  Algeria   25    0  14  0.7     39  0.017949
# 1  AF   Angola  217   57  45  5.9    319  0.018495

# %%
# [2-53] 대륙별 주류 소비량 평균을 계산해 봅니다.
df.groupby('대륙').mean()
# Out:
# <ipython-input-95-d13c015d5e0b>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('대륙').mean()
#             맥주         증류주          와인       알코올       주류소비량     알코올비율
# 대륙
# AF   61.471698   16.339623   16.264151  3.007547   94.075472  0.049741
# AS   37.045455   60.840909    9.068182  2.170455  106.954545  0.016359
# EU  193.777778  132.555556  142.222222  8.617778  468.555556  0.017527
# NA  145.434783  165.739130   24.521739  5.995652  335.695652  0.017854
# OC   89.687500   58.437500   35.625000  3.381250  183.750000  0.016895
# SA  175.083333  114.750000   62.416667  6.308333  352.250000  0.017868

# %%
# [2-54] 대륙별 주류 소비량 중앙값을 계산해 봅니다.
df.groupby('대륙').median()
# Out:
# <ipython-input-96-5d102a929dad>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('대륙').median()
#        맥주    증류주     와인    알코올  주류소비량     알코올비율
# 대륙
# AF   32.0    3.0    2.0   2.30   49.0  0.021951
# AS   17.5   16.0    1.0   1.20   68.0  0.017843
# EU  219.0  122.0  128.0  10.00  541.0  0.017865
# NA  143.0  137.0   11.0   6.30  349.0  0.017818
# OC   52.5   37.0    8.5   1.75   98.5  0.017732
# SA  162.5  108.5   12.0   6.85  383.0  0.017786

# %%
df.groupby('대륙').max()
# Out:
#                 국가   맥주  증류주   와인   알코올  주류소비량     알코올비율
# 대륙
# AF        Zimbabwe  376  152  233   9.1    504  0.266667
# AS           Yemen  247  326  123  11.5    646  0.059394
# EU  United Kingdom  361  373  370  14.4    695  0.025853
# NA             USA  285  438  100  11.9    665  0.018133
# OC         Vanuatu  306  254  212  10.4    545  0.020350
# SA       Venezuela  333  302  221   8.3    439  0.018907

# %%
# [2-55] 대륙별 맥주 소비량 평균은?
df.groupby('대륙')[['맥주']].mean()
# Out:
#             맥주
# 대륙
# AF   61.471698
# AS   37.045455
# EU  193.777778
# NA  145.434783
# OC   89.687500
# SA  175.083333

# %%
df.groupby('대륙')[['맥주', '와인']].mean()
# Out:
#             맥주          와인
# 대륙
# AF   61.471698   16.264151
# AS   37.045455    9.068182
# EU  193.777778  142.222222
# NA  145.434783   24.521739
# OC   89.687500   35.625000
# SA  175.083333   62.416667

# %%
df['맥주'].mean() # 전세계 맥주 소비량
# Out:
# 106.16062176165804

# %%
# [2-56] 전세계 맥주 소비량 평균보다 많은 맥주를 소비하는 대륙은?
temp = df.groupby('대륙')[['맥주']].mean()
temp[temp['맥주'] > df['맥주'].mean()]
# Out:
#             맥주
# 대륙
# EU  193.777778
# NA  145.434783
# SA  175.083333

# %%
# [2-57] 대륙별 맥주와 와인 소비량의 평균, 중앙값, 최대값은?
df.groupby('대륙')[['맥주', '와인']].agg(['mean', 'median', max])
# Out:
#             맥주                      와인
#           mean median  max        mean median  max
# 대륙
# AF   61.471698   32.0  376   16.264151    2.0  233
# AS   37.045455   17.5  247    9.068182    1.0  123
# EU  193.777778  219.0  361  142.222222  128.0  370
# NA  145.434783  143.0  285   24.521739   11.0  100
# OC   89.687500   52.5  306   35.625000    8.5  212
# SA  175.083333  162.5  333   62.416667   12.0  221

# %%
# [2-58] pivot_table을 사용하여 대륙별(index), '맥주'와 '와인'의 mean, median, max 값을 구합니다.
# 결과 참조
df.pivot_table(index = '대륙', values = ['맥주', '와인'], aggfunc = ['mean', 'median', 'max'])
# Out:
#           mean             median         max
#             맥주          와인     맥주     와인   맥주   와인
# 대륙
# AF   61.471698   16.264151   32.0    2.0  376  233
# AS   37.045455    9.068182   17.5    1.0  247  123
# EU  193.777778  142.222222  219.0  128.0  361  370
# NA  145.434783   24.521739  143.0   11.0  285  100
# OC   89.687500   35.625000   52.5    8.5  306  212
# SA  175.083333   62.416667  162.5   12.0  333  221

# %%
# [2-59] pivot_table을 사용하여 대륙별(columns), '맥주'와 '와인'의 mean, median값을 구합니다.
# 결과 참조
df.pivot_table(columns = '대륙', values = ['맥주', '와인'], aggfunc = ['mean', 'median'])
# Out:
#          mean                                              ... median         \
# 대륙         AF         AS          EU          NA       OC  ...     AS     EU
# 맥주  61.471698  37.045455  193.777778  145.434783  89.6875  ...   17.5  219.0
# 와인  16.264151   9.068182  142.222222   24.521739  35.6250  ...    1.0  128.0
#
#
# 대륙     NA    OC     SA
# 맥주  143.0  52.5  162.5
# 와인   11.0   8.5   12.0
#
# [2 rows x 12 columns]

# %%
# [2-60] groupby를 사용하여 대륙별, '맥주'와 '와인'의 mean, median, max 값을 구합니다.
df.groupby('대륙')[['맥주', '와인']].agg(['mean', 'median', 'max'])
# Out:
#             맥주                      와인
#           mean median  max        mean median  max
# 대륙
# AF   61.471698   32.0  376   16.264151    2.0  233
# AS   37.045455   17.5  247    9.068182    1.0  123
# EU  193.777778  219.0  361  142.222222  128.0  370
# NA  145.434783  143.0  285   24.521739   11.0  100
# OC   89.687500   52.5  306   35.625000    8.5  212
# SA  175.083333  162.5  333   62.416667   12.0  221
